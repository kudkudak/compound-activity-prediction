# %%
from data_api import *
print proteins, fingerprints
# Out:
#  ['5ht7', '5ht6', 'SERT', '5ht2c', '5ht2a', 'hiv_integrase', 'h1', 'hERG', 'cathepsin', 'hiv_protease', 'M1', 'd2'] ['EstateFP', 'ExtFP', 'KlekFP', 'KlekFPCount', 'MACCSFP', 'PubchemFP', 'SubFP', 'SubFPCount']

# %% [markdown]
# ## RBF: 2 4 (SERT/MACCSFP)
#
# [ 0.91850589,  0.90536383,  0.90097894,  0.90874151,  0.90855648,
# 0.9108104 ,  0.86907926,  0.90023885,  0.90855648,  0.89628068]
#
# 0.902711231337
#
# ### Linear K=20
#
# [ 0.90305645,  0.90305645,  0.88974299,  0.90153401,  0.90892653,
#         0.892737  ,  0.87318341,  0.91576398,  0.88926361,  0.91759298]
#
#  0.899485739483
#
#
# ## RBF: 1, 4 (5ht6/MACCSFP)
#
# array([ 0.9126558 ,  0.90426372,  0.82273983,  0.8769246 ,  0.90633636,
#         0.80132254,  0.92439795,  0.8555073 ,  0.81938413,  0.85886301])}}
#
# 0.868239523998
#
# ### Linear K=15
#
# 88,2% ([ 0.82780441,  0.8908409 ,  0.89291354,  0.8941966 ,  0.94038689,
#         0.85471773,  0.93703119,  0.85007896,  0.87149625,  0.86814054]
#
# ### Linear K=20
#
# 89,3% [ 0.85302013,  0.90890249,  0.8941966 ,  0.8941966 ,  0.94502566,
#         0.8874852 ,  0.93367548,  0.88284643,  0.85343466,  0.88077379])
#
# ## RBF: 9,3 (hiv_protease/KlekFPCount)
#
#  0.88582982,  0.91044304,  0.8390647 ,  0.88512658,  0.84068214,
#         0.89206349,  0.84722668,  0.88179062,  0.83599073,  0.86579276]
#
# 0.868401054965
#
# ### Linear K=15
#
# [ 0.87317159,  0.89222925,  0.87556259,  0.87563291,  0.85812236,
#         0.88968254,  0.85601926,  0.88509007,  0.84735152,  0.88007847]
#
# 0.873294057157
#
# ### Linear K=20
#
# [ 0.87471871,  0.88586498,  0.87872714,  0.88751758,  0.84859353,
#         0.88492063,  0.84246478,  0.88423399,  0.86261816,  0.86334938]
#
# 0.871300888582
#
# ## RBF: 7, 1 (hERG/ExtFP)
#
# [ 0.87423423,  0.79099099,  0.77322799,  0.71984199,  0.81097065,
#         0.80984199,  0.80160778,  0.81298659,  0.78688902,  0.80842585]
#
#  0.79890170896
#
# ### Linear K=15
#
# [ 0.85522523,  0.8040991 ,  0.79776524,  0.78146727,  0.82002257,
#         0.86760722,  0.75406551,  0.8165108 ,  0.81425347,  0.83348689]
#
# 0.814450329885
#
# ### Linear K=20
#
# [ 0.86175676,  0.87554054,  0.79356659,  0.81325056,  0.8221219 ,
#         0.87534989,  0.81199613,  0.84617865,  0.80418759,  0.82459575])
#
# 0.832854436046
#
# ## RBF: 8, 6 (cathepsin/subfP)
#
# [ 0.76210526,  0.79684211,  0.78736842,  0.87744681,  0.81744681,
#         0.83289007,  0.92641844,  0.81117021,  0.88430851,  0.86303191])}}
#
# 0.835902855543
#
# ### Linear K=15
#
# [ 0.87578947,  0.82526316,  0.83052632,  0.85489362,  0.86553191,
#         0.82712766,  0.8998227 ,  0.8373227 ,  0.91489362,  0.91489362]
#
# 0.864606476297
#
# ### Linear K=20
#
# [ 0.83578947,  0.78526316,  0.83578947,  0.88553191,  0.92553191,
#         0.85328014,  0.91046099,  0.83200355,  0.92553191,  0.8679078 ]
#
# 0.865709033221
#
# ## RBF: 5, 0 (hiv_integrase/EstateFP)
#
# [ 0.7020751 ,  0.77391304,  0.70652174,  0.89565217,  0.78956044,
#         0.86758242,  0.79505495,  0.88956044,  0.82857143,  0.87857143]
#
# 0.812706315424
#
# ### Linear K=15
#
# [ 0.8201581 ,  0.73478261,  0.76847826,  0.77391304,  0.76208791,
#         0.87362637,  0.80659341,  0.88461538,  0.65659341,  0.82307692]
#
# 0.79039254224
#
# ### Linear K=20
#
# [ 0.71294466,  0.84673913,  0.69021739,  0.89021739,  0.86758242,
#         0.89010989,  0.71758242,  0.92857143,  0.81208791,  0.8010989 ]
#
# 0.815715154411
